# %%
from env import run_with_model
# Out:
# device cuda is ready

# %%
run_with_model()
# Out:
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# ...
